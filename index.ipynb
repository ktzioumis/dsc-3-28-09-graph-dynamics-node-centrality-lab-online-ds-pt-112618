# %% [markdown]
# # Network Dynamics: Node Centrality - Lab
#
# ## Introduction
# In this lab, we shall put the node centrality measures in to practice to analyze the character interactions in graph structure from the popular series of novels called ""A Song of Ice and Fire" by George R. R. Martin. The of famous HBO series "Game of Thrones" is derived from this saga. In this lab, we shall calculate different centrality measures to identify the the importance of characters as the story progresses.
#
#
# ## Objectives
# You will be able to:
# - Understand and explain network centrality and its importance in graph analysis
# - Understand and calculate Degree, Closeness, Betweenness and Eigenvector centrality measures
# - Describe the use case for several centrality measures

# %% [markdown]
# ## ASIOF (A Song of Ice and Fire) Character Interaction Graph Data
#
# A. J. Beveridge, and J. Shan  created a network from books "A song of ice and fire" by extracting relationships between characters of the story. [The dataset is available at Github](https://github.com/mathbeveridge/asoiaf)
# as an interaction network which was built as
# > Parse the text and build a graph by connecting (creating an edge) two characters (nodes of the graph) whenever their names appear within 15 words. The edge weight corresponds to the number of interactions.
#
# <img src="parse.png" width=300>
#
# The datasets have been made available for you in the repo. You are encouraged to [visit A. J. Beveridge's blog](https://networkofthrones.wordpress.com) to see how this dataset is created, and different network analysis activities which are being performed with this dataset. The image you see below, has been created using same datasets. The blog gives you information on this and more experiments. For this lab, we shall focus more on graph analysis than visualizations.
#
# <img src="got.png" width=800>
#
# Let's get on with it.

# %% [markdown]
# ## Load necessary libraries
#
# - Let's give you a head start by loading the libraries that you might need for this experiment.

# %%
import pandas as pd
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

# %% [markdown]
# ##  Load the dataset
#
# The dataset is available for all 5 books, with two CSV files for each book. One contains nodes data as adjacency matrix and other carries edges data as edge list, e.g. for book 1, `asoiaf-book1-edges.csv` and `asoiaf-book1-nodes.csv`. So we have 10 files in total.
#
# - Read edge data for all books into pandas dataframe:  book1_df .. book5_df.
#
# How about using a for loop to do this in one go - optional.

# %%
# Load edges into dataframes
book1_df=pd.read_csv('asiof/asoiaf-book1-edges.csv')
book2_df=pd.read_csv('asiof/asoiaf-book2-edges.csv')
book3_df=pd.read_csv('asiof/asoiaf-book3-edges.csv')
book4_df=pd.read_csv('asiof/asoiaf-book4-edges.csv')
book5_df=pd.read_csv('asiof/asoiaf-book5-edges.csv')

# %%
book1_df.head()
# Out:
#                             Source              Target        Type  weight  \
# 0                   Addam-Marbrand     Jaime-Lannister  Undirected       3
# 1                   Addam-Marbrand     Tywin-Lannister  Undirected       6
# 2                Aegon-I-Targaryen  Daenerys-Targaryen  Undirected       5
# 3                Aegon-I-Targaryen        Eddard-Stark  Undirected       4
# 4  Aemon-Targaryen-(Maester-Aemon)      Alliser-Thorne  Undirected       4
#
#    book
# 0     1
# 1     1
# 2     1
# 3     1
# 4     1

# %% [markdown]
# ## Create Empty graph instances for each book

# %%
# Create empty instances for each book above
G1=nx.Graph()
G3=nx.Graph()
G4=nx.Graph()
G5=nx.Graph()
G2=nx.Graph()

# %% [markdown]
# ## Create Graph
# - Read the edge lists from the dataframes above into relevant graphs.
# - inspect the contents of graph to get an idea about the data structures contained within

# %%
# Read edge lists into datafram
# df.iterrows to iterate through rows of a data frame,
for row in book1_df.iterrows():
    G1.add_edge(row[1][0],row[1][1],weight=row[1]['weight'])
for row in book2_df.iterrows():
    G2.add_edge(row[1][0],row[1][1],weight=row[1]['weight'])
for row in book3_df.iterrows():
    G3.add_edge(row[1][0],row[1][1],weight=row[1]['weight'])
for row in book4_df.iterrows():
    G4.add_edge(row[1][0],row[1][1],weight=row[1]['weight'])
for row in book5_df.iterrows():
    G5.add_edge(row[1][0],row[1][1],weight=row[1]['weight'])

# %%
G4.edges(data=True)
# Out:
# EdgeDataView([('Addam-Marbrand', 'Brynden-Tully', {'weight': 3}), ('Addam-Marbrand', 'Cersei-Lannister', {'weight': 3}), ('Addam-Marbrand', 'Jaime-Lannister', {'weight': 8}), ('Addam-Marbrand', 'Lyle-Crakehall', {'weight': 4}), ('Brynden-Tully', 'Catelyn-Stark', {'weight': 3}), ('Brynden-Tully', 'Daven-Lannister', {'weight': 3}), ('Brynden-Tully', 'Edmure-Tully', {'weight': 15}), ('Brynden-Tully', 'Edwyn-Frey', {'weight': 3}), ('Brynden-Tully', 'Emmon-Frey', {'weight': 7}), ('Brynden-Tully', 'Jaime-Lannister', {'weight': 18}), ('Brynden-Tully', 'Lyle-Crakehall', {'weight': 4}), ('Brynden-Tully', 'Ryman-Frey', {'weight': 3}), ('Cersei-Lannister', 'Aerys-II-Targaryen', {'weight': 3}), ('Cersei-Lannister', 'Aurane-Waters', {'weight': 9}), ('Cersei-Lannister', 'Baelor-I-Targaryen', {'weight': 5}), ('Cersei-Lannister', 'Balman-Byrch', {'weight': 7}), ('Cersei-Lannister', 'Blue-Bard', {'weight': 7}), ('Cersei-Lannister', 'Boros-Blount', {'weight': 3}), ('Cersei-Lannister', 'Bronn', {'weight': 4}), ('Cersei-Lannister', 'Dorcas', {'weight': 18}), ('Cersei-Lannister', 'Dunsen', {'weight': 4}), ('Cersei-Lannister', 'Eddard-Stark', {'weight': 3}), ('Cersei-Lannister', 'Falyse-Stokeworth', {'weight': 14}), ('Cersei-Lannister', 'Garlan-Tyrell', {'weight': 3}), ('Cersei-Lannister', 'Garth-Tyrell', {'weight': 3}), ('Cersei-Lannister', 'Gregor-Clegane', {'weight': 6}), ('Cersei-Lannister', 'Gyles-Rosby', {'weight': 18}), ('Cersei-Lannister', 'Harys-Swyft', {'weight': 4}), ('Cersei-Lannister', 'High-Septon-(Tyrions)', {'weight': 3}), ('Cersei-Lannister', 'High-Sparrow', {'weight': 24}), ('Cersei-Lannister', 'Ilyn-Payne', {'weight': 6}), ('Cersei-Lannister', 'Jaime-Lannister', {'weight': 49}), ('Cersei-Lannister', 'Jalabhar-Xho', {'weight': 3}), ('Cersei-Lannister', 'Jocelyn-Swyft', {'weight': 13}), ('Cersei-Lannister', 'Joffrey-Baratheon', {'weight': 21}), ('Cersei-Lannister', 'Jon-Snow', {'weight': 3}), ('Cersei-Lannister', 'Kevan-Lannister', {'weight': 9}), ('Cersei-Lannister', 'Lancel-Lannister', {'weight': 9}), ('Cersei-Lannister', 'Loras-Tyrell', {'weight': 24}), ('Cersei-Lannister', 'Mace-Tyrell', {'weight': 17}), ('Cersei-Lannister', 'Maegor-I-Targaryen', {'weight': 3}), ('Cersei-Lannister', 'Maggy', {'weight': 5}), ('Cersei-Lannister', 'Margaery-Tyrell', {'weight': 67}), ('Cersei-Lannister', 'Mark-Mullendore', {'weight': 3}), ('Cersei-Lannister', 'Melara-Hetherspoon', {'weight': 5}), ('Cersei-Lannister', 'Meryn-Trant', {'weight': 15}), ('Cersei-Lannister', 'Moon-Boy', {'weight': 5}), ('Cersei-Lannister', 'Myrcella-Baratheon', {'weight': 4}), ('Cersei-Lannister', 'Olenna-Redwyne', {'weight': 6}), ('Cersei-Lannister', 'Orton-Merryweather', {'weight': 9}), ('Cersei-Lannister', 'Osfryd-Kettleblack', {'weight': 8}), ('Cersei-Lannister', 'Osmund-Kettleblack', {'weight': 25}), ('Cersei-Lannister', 'Osney-Kettleblack', {'weight': 24}), ('Cersei-Lannister', 'Petyr-Baelish', {'weight': 7}), ('Cersei-Lannister', 'Pycelle', {'weight': 15}), ('Cersei-Lannister', 'Qyburn', {'weight': 27}), ('Cersei-Lannister', 'Rafford', {'weight': 4}), ('Cersei-Lannister', 'Raynard', {'weight': 3}), ('Cersei-Lannister', 'Rhaegar-Targaryen', {'weight': 5}), ('Cersei-Lannister', 'Robert-Baratheon', {'weight': 29}), ('Cersei-Lannister', 'Sansa-Stark', {'weight': 6}), ('Cersei-Lannister', 'Senelle', {'weight': 9}), ('Cersei-Lannister', 'Stannis-Baratheon', {'weight': 9}), ('Cersei-Lannister', 'Taena-of-Myr', {'weight': 46}), ('Cersei-Lannister', 'Tallad', {'weight': 4}), ('Cersei-Lannister', 'Tommen-Baratheon', {'weight': 80}), ('Cersei-Lannister', 'Tyrion-Lannister', {'weight': 36}), ('Cersei-Lannister', 'Tywin-Lannister', {'weight': 14}), ('Cersei-Lannister', 'Unella', {'weight': 3}), ('Cersei-Lannister', 'Varys', {'weight': 7}), ('Cersei-Lannister', 'Walder-Frey', {'weight': 5}), ('Jaime-Lannister', 'Aerys-II-Targaryen', {'weight': 6}), ('Jaime-Lannister', 'Amerei-Frey', {'weight': 6}), ('Jaime-Lannister', 'Balon-Swann', {'weight': 3}), ('Jaime-Lannister', 'Beric-Do ...

# %% [markdown]
# ## Finding important nodes (characters)
#
# Let's use and compare different centralities measures we saw earlier to identify importance of nodes in this network. There is no one right way of calaculating it, every approach has a different meaning.
#
# ## Calculate Degree Centrality
# Degree centrality which is defined by degree of a node (number of neighbors) divided by a noramlizing factor n-1 where n is the number of nodes.
#
# - __Find the neighbours of '**Catelyn-Stark**' from book 1.__

# %%
# Neighbors for catelyn stark
list(G1.neighbors('Catelyn-Stark'))
# Out:
# ['Arya-Stark',
#  'Bran-Stark',
#  'Bronn',
#  'Brynden-Tully',
#  'Cersei-Lannister',
#  'Colemon',
#  'Donnel-Waynwood',
#  'Eddard-Stark',
#  'Edmure-Tully',
#  'Eon-Hunter',
#  'Hallis-Mollen',
#  'Hoster-Tully',
#  'Jaime-Lannister',
#  'Joffrey-Baratheon',
#  'Jon-Arryn',
#  'Jon-Snow',
#  'Jon-Umber-(Greatjon)',
#  'Luwin',
#  'Lysa-Arryn',
#  'Marillion',
#  'Masha-Heddle',
#  'Moreo-Tumitis',
#  'Mya-Stone',
#  'Mychel-Redfort',
#  'Nestor-Royce',
#  'Petyr-Baelish',
#  'Rickard-Karstark',
#  'Rickon-Stark',
#  'Robb-Stark',
#  'Robert-Arryn',
#  'Robert-Baratheon',
#  'Rodrik-Cassel',
#  'Sansa-Stark',
#  'Stevron-Frey',
#  'Theon-Greyjoy',
#  'Tyrion-Lannister',
#  'Tytos-Blackwood',
#  'Tywin-Lannister',
#  'Vardis-Egen',
#  'Varys',
#  'Walder-Frey',
#  'Wendel-Manderly',
#  'Willis-Wode']

# %% [markdown]
#  `nx.degree_centrality(graph)` returns a dictionary where keys are the nodes and values are the corresponding degree centrality.
#
# - __Find the five most and least important characters from book 1 according to degree centrality__

# %%
# Five most important characters from book 1 according to degree centrality
# dict.items gives dict-items object similar to list of tuples
dc_dict1=nx.degree_centrality(G1)
sorted(dc_dict1.items(),key=lambda x:x[1], reverse=True)[0:5]
# Out:
# [('Eddard-Stark', 0.3548387096774194),
#  ('Robert-Baratheon', 0.2688172043010753),
#  ('Tyrion-Lannister', 0.24731182795698928),
#  ('Catelyn-Stark', 0.23118279569892475),
#  ('Jon-Snow', 0.19892473118279572)]

# %%
# Five least important characters from book 1 according to degree centrality
sorted(dc_dict1.items(),key=lambda x:x[1])[0:5]
# Out:
# [('Clydas', 0.005376344086021506),
#  ('Arthur-Dayne', 0.005376344086021506),
#  ('Arys-Oakheart', 0.005376344086021506),
#  ('Mance-Rayder', 0.005376344086021506),
#  ('Thoros-of-Myr', 0.005376344086021506)]

# %%
list(dc_dict1.items())[2][0]
# Out:
# 'Tywin-Lannister'

# %% [markdown]
# - __Plot and explain histogram from degree centrality values, calculated from book 1, and comment on the output__

# %%
# Plot a histogram of degree centrality
plt.hist(dc_dict1.values())
plt.xlabel('degree centrality')
plt.ylabel('count')
plt.show()

# %%
# Your observations here 
mostly very low, a few high value popular characters

# %% [markdown]
# ##  Weighted Degree Centrality
#
# - Create a new centrality measure as a function, `weighted_degree_centrality(Graph)` which takes in Graph and the returns a weighted degree centrality dictionary.
#
# [Refer to this paper to get an insight into this approacj](https://journals.plos.org/plosone/article?id=10.1371/journal.pone.0165781)
#
# Weighted degree is calculated by:
#
# 1) __Sum the weight of the all edges of a node__
#
# 2) __Normalize the weighted degree by the total weight of the graph i.e. sum of weighted degrees of all nodes__
#
# 3) __Calculated weighted degree centrality for book 1 using this function__

# %%
def weighted_degree_centrality(G):
    wdc_dict=dict.fromkeys(G.nodes(),0)
    for n in G.nodes():
        wdc_dict[n]+=G.degree(n,weight='weight')
    gsum=sum(wdc_dict.values())
    for k,v in wdc_dict.items():
        wdc_dict[k]=v/gsum
    return wdc_dict

# %%
G1.degree('Jon-Snow',weight='weight')
# Out:
# 784

# %%
weighted_degree_centrality(G1)
# Out:
# {'Addam-Marbrand': 0.0006109150149334781,
#  'Jaime-Lannister': 0.01635894651099647,
#  'Tywin-Lannister': 0.012286179744773282,
#  'Aegon-I-Targaryen': 0.0006109150149334781,
#  'Daenerys-Targaryen': 0.030070594623947868,
#  'Eddard-Stark': 0.08715720879717621,
#  'Aemon-Targaryen-(Maester-Aemon)': 0.005023079011675265,
#  'Alliser-Thorne': 0.005430355688297583,
#  'Bowen-Marsh': 0.0019006244909041542,
#  'Chett': 0.001289709475970676,
#  'Clydas': 0.00033939723051859896,
#  'Jeor-Mormont': 0.012286179744773282,
#  'Jon-Snow': 0.05321748574531632,
#  'Samwell-Tarly': 0.01004615802335053,
#  'Aerys-II-Targaryen': 0.0025115395058376323,
#  'Brandon-Stark': 0.0027830572902525115,
#  'Gerold-Hightower': 0.0011539505837632365,
#  'Jon-Arryn': 0.011471626391528645,
#  'Robert-Baratheon': 0.06387455878360032,
#  'Aggo': 0.0024436600597339125,
#  'Drogo': 0.017377138202552267,
#  'Jhogo': 0.002918816182459951,
#  'Jorah-Mormont': 0.010453434699972848,
#  'Quaro': 0.0014254683681781156,
#  'Rakharo': 0.001629106706489275,
#  'Albett': 0.0007466739071409177,
#  'Halder': 0.0038012489818083084,
#  'Rast': 0.0017648655986967146,
#  'Grenn': 0.005769752918816182,
#  'Pypar': 0.007263100733098018,
#  'Tyrion-Lannister': 0.044121639967417865,
#  'Alyn': 0.0021721422753190334,
#  'Harwin': 0.0012218300298669563,
#  'Jory-Cassel': 0.010317675807765408,
#  'Tomard': 0.0028509367363562313,
#  'Arthur-Dayne': 0.00027151778441487917,
#  'Arya-Stark': 0.02918816182459951,
#  'Benjen-Stark': 0.0070594623947868584,
#  'Bran-Stark': 0.03604398588107521,
#  'Catelyn-Stark': 0.03529731197393429,
#  'Cersei-Lannister': 0.028780885147977192,
#  'Desmond': 0.00047515612272603855,
#  'Ilyn-Payne': 0.002918816182459951,
#  'Jeyne-Poole': 0.003665490089600869,
#  'Joffrey-Baratheon': 0.028645126255769753,
#  'Meryn-Trant': 0.0024436600597339125,
#  'Mordane': 0.00957100190062449,
#  'Mycah': 0.0033939723051859896,
#  'Myrcella-Baratheon': 0.003665490089600869,
#  'Petyr-Baelish': 0.021246266630464295,
#  'Rickon-Stark': 0.00665218571816454,
#  'Robb-Stark': 0.03502579418951941,
#  'Rodrik-Cassel': 0.008417051316861254,
#  'Sandor-Clegane': 0.009163725224002172,
#  'Sansa-Stark': 0.03699429812652729,
#  'Syrio-Forel': 0.0021042628292153136,
#  'Tommen-Baratheon': 0.0025115395058376323,
#  'Vayon-Poole': 0.0019006244909041542,
#  'Yoren': 0.002240021721422753,
#  'Arys-Oakheart': 0.00020363833831115938,
#  'Balon-Greyjoy': 0.00047515612272603855,
#  'Balon-Swann': 0.00040727667662231876,
#  'Renly-Baratheon': 0.012625576975291881,
#  'Barristan-Selmy': 0.00970676079283193,
#  'Boros-Blount': 0.0017648655986967146,
#  'Pycelle': 0.010181916915557969,
#  'Varys': 0.015680152049959272,
#  'Jaremy-Rykker': 0.001629106706489275,
#  'Luwin': 0.014254683681781156,
#  'Mance-Rayder': 0.00020363833831115938,
#  'Theon-Greyjoy': 0.009027966331794732,
#  'Waymar-Royce': 0.002307901167526473,
#  'Beric-Dondarrion': 0.0019006244909041542,
#  'Gregor-Clegane': 0.005023079011675265,
#  'Loras-Tyrell': 0.005294596796090144,
#  'Thoros-of-Myr': 0.00033939723051859896,
#  'Hali': 0.00020363833831115938,
#  'Hallis-Mollen': 0.0025115395058376323,
#  'Hodor': 0.0035297311973934292,
#  'Hullen': 0.0013575889220743959,
#  'Joseth': 0.00047515612272603855,
#  'Nan': 0.002240021721422753,
#  'Osha': 0.0021042628292153136,
#  'Rickard-Karstark': 0.0031224545207711105,
#  'Rickard-Stark': 0.00047515612272603855,
#  'Stiv': 0.00047515612272603855,
#  'Lyanna-Stark': 0.0024436600597339125,
#  'Bronn': 0.007398859625305457,
#  'Chiggen': 0.0010860711376595167,
#  'Marillion': 0.001968503937007874,
#  'Shae': 0.0010181916915557969,
#  'Shagga': 0.002986695628563671,
#  'Vardis-Egen': 0.0025115395058376323,
#  'Willis-Wode': 0.0019006244909041542,
#  'Brynden-Tully': 0.004683681781156666,
#  'Edmure-Tully': 0.00325821341297855,
#  'Hoster-Tully': 0.001629106706489275,
#  'Lysa-Arryn': 0.009367363562313331,
#  'Nestor-Royce': 0.00040727667662231876,
#  'Walder-Frey': 0.0027830572902525115,
#  'Colemon': 0.00047515612272603855,
#  'Donnel-Waynwood': 0.00020363833831115938,
#  'Eon-Hunter': 0.0006109150149334781,
#  'Jon-Umber-(Greatjon)': 0.002647298398045072,
#  'Masha-Heddle': 0.00033939723051859896,
#  'Moreo-Tumitis': 0.00020363833831115938,
#  'Mya-Stone': 0.0006109150149334781,
#  'Mychel-Redfort': 0.00020363833831115938,
#  'Robert-Arryn': 0.0013575889220743959,
#  'Stevron-Frey': 0.0005430355688297583,
#  'Tytos-Blackwood': 0.0006787944610371979,
#  'Wendel-Manderly': 0.00040727667662231876,
#  'Cayn': 0.0010860711376595167,
#  'Janos-Slynt': 0.0016969861525929948,
#  'Stannis-Baratheon': 0.007127341840890578,
#  'Chella': 0.00033939723051859896,
#  'Clement-Piper': 0.00027151778441487917,
#  'Karyl-Vance': 0.0007466739071409177,
#  'Cohollo': 0.001968503937007874,
#  'Haggo': 0.0030545750746673907,
#  'Qotho': 0.004615802335052946,
#  'Conn': 0.0013575889220743959,
#  'Coratt': 0.00033939723051859896,
#  'Doreah': 0.0034618517512897094,
#  'Eroeh': 0.00033939723051859896,
#  'Illyrio-Mopatis': 0.0047515612272603855,
#  'Irri': 0.005498235134401303,
#  'Jhiqui': 0.0040727667662231876,
#  'Mirri-Maz-Duur': 0.004276405104534347,
#  'Rhaegar-Targaryen': 0.003597610643497149,
#  'Viserys-Targaryen': 0.007127341840890578,
#  'Danwell-Frey': 0.0006109150149334781,
#  'Hosteen-Frey': 0.00040727667662231876,
#  'Jared-Frey': 0.00040727667662231876,
#  'Dareon': 0.00040727667662231876,
#  'Daryn-Hornwood': 0.00040727667662231876,
#  'Torrhen-Karstark': 0.0007466739071409177,
#  'Dolf': 0.00047515612272603855,
#  'Donal-Noye': 0.00047515612272603855,
#  'Jommo': 0.00040727667662231876,
#  'Ogo': 0.0012218300298669563,
#  'Rhaego': 0.00033939723051859896,
#  'Dywen': 0.00027151778441487917,
#  'Galbart-Glover': 0.0015612272603855552,
#  'Gendry': 0.00020363833831115938,
#  'High-Septon-(fat_one)': 0.0005430355688297583,
#  'Howland-Reed': 0.00020363833831115938,
#  'Jacks': 0.00027151778441487917,
#  'Joss': 0.00033939723051859896,
#  'Marq-Piper': 0.0012218300298669563,
#  'Porther': 0.00027151778441487917,
#  'Raymun-Darry': 0.0008145533532446375,
#  'Tobho-Mott': 0.00047515612272603855,
#  'Tregar': 0.00027151778441487917,
#  'Varly': 0.00027151778441487917,
#  'Wyl-(guard)': 0.0010181916915557969,
#  'Wylla': 0.00020363833831115938,
#  'Fogo': 0.00027151778441487917,
#  'Roose-Bolton': 0.001289709475970676,
#  'Gared': 0.001968503937007874,
#  'Will-(prologue)': 0.0020363833831115938,
#  'Oswell-Whent': 0.00020363833831115938,
#  'Todder': 0.0021042628292153136,
#  'Gunthor-son-of-Gurn': 0.00047515612272603855,
#  'Harys-Swyft': 0.00020363833831115938,
#  'Heward': 0.0005430355688297583,
#  'Hobb': 0.00033939723051859896,
#  'Hugh': 0.00020363833831115938,
#  'Jafer-Flowers': 0.00020363833831115938,
#  'Kevan-Lannister': 0.0019006244909041542,
#  'Matthar': 0.00020363833831115938,
#  'Othor': 0.00033939723051859896,
#  'Maege-Mormont': 0.0005430355688297583,
#  'Jonos-Bracken': 0.00020363833831115938,
#  'Jyck': 0.0007466739071409177,
#  'Morrec': 0.0006787944610371979,
#  'Kurleket': 0.00033939723051859896,
#  'Lancel-Lannister': 0.00020363833831115938,
#  'Leo-Lefford': 0.00027151778441487917,
#  'Mace-Tyrell': 0.00040727667662231876,
#  'Lyn-Corbray': 0.00020363833831115938,
#  'Paxter-Redwyne': 0.00020363833831115938,
#  'Maegor-I-Targaryen': 0.00027151778441487917,
#  'Mord': 0.0013575889220743959,
#  'Randyll-Tarly': 0.00033939723051859896,
#  'Timett': 0.00047515612272603855,
#  'Ulf-son-of-Umar': 0.00027151778441487917}

# %%
# Uncomment below to run


plt.hist(list(weighted_degree_centrality(G1).values()))
#plt.show()
# Out:
# (array([157.,  17.,   1.,   4.,   4.,   1.,   1.,   1.,   0.,   1.]),
#  array([0.00020364, 0.008899  , 0.01759435, 0.02628971, 0.03498507,
#         0.04368042, 0.05237578, 0.06107114, 0.06976649, 0.07846185,
#         0.08715721]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# - __Get the top 10 characters from book 1, based on weighted degree centrality and compare with the results of simple degree centrality. Record your observations below__

# %%
# Weighted DC
sorted(weighted_degree_centrality(G1).items(), key=lambda x:x[1], reverse=True)[0:10]
# Out:
# [('Eddard-Stark', 0.08715720879717621),
#  ('Robert-Baratheon', 0.06387455878360032),
#  ('Jon-Snow', 0.05321748574531632),
#  ('Tyrion-Lannister', 0.044121639967417865),
#  ('Sansa-Stark', 0.03699429812652729),
#  ('Bran-Stark', 0.03604398588107521),
#  ('Catelyn-Stark', 0.03529731197393429),
#  ('Robb-Stark', 0.03502579418951941),
#  ('Daenerys-Targaryen', 0.030070594623947868),
#  ('Arya-Stark', 0.02918816182459951)]

# %%
# Un-weighted DC
sorted(nx.degree_centrality(G1).items(),key=lambda x:x[1],reverse = True)[0:10]
# Out:
# [('Eddard-Stark', 0.3548387096774194),
#  ('Robert-Baratheon', 0.2688172043010753),
#  ('Tyrion-Lannister', 0.24731182795698928),
#  ('Catelyn-Stark', 0.23118279569892475),
#  ('Jon-Snow', 0.19892473118279572),
#  ('Robb-Stark', 0.18817204301075272),
#  ('Sansa-Stark', 0.18817204301075272),
#  ('Bran-Stark', 0.17204301075268819),
#  ('Cersei-Lannister', 0.16129032258064518),
#  ('Joffrey-Baratheon', 0.16129032258064518)]

# %% [markdown]
# # Your observations here
# very similar lists
# eddard-stark remains at the top of both lists
# some go up some go down
# lannisters and starks

# %% [markdown]
# - __ Confirm that sum of weighted degree centralitity value for all nodes sum up to 1 i.e. normalization__

# %%
# Uncomment to run 

sum(list(weighted_degree_centrality(G1).values()))
# Out:
# 1.0000000000000002

# %% [markdown]
# ## Betweenness centrality
#
# - __Calculate the weighted and un-weighted "Betweenness" centrality for book 2, and compare top ten characters as above__
# - __Comment on the results__

# %%
# Unweighted Betweenness Centrality
sorted(nx.betweenness_centrality(G1).items(), key=lambda x:x[1], reverse=True)[0:10]
# Out:
# [('Eddard-Stark', 0.2696038913836117),
#  ('Robert-Baratheon', 0.21403028397371796),
#  ('Tyrion-Lannister', 0.1902124972697492),
#  ('Jon-Snow', 0.17158135899829566),
#  ('Catelyn-Stark', 0.1513952715347627),
#  ('Daenerys-Targaryen', 0.08627015537511595),
#  ('Robb-Stark', 0.07298399629664767),
#  ('Drogo', 0.06481224290874964),
#  ('Bran-Stark', 0.05579958811784442),
#  ('Sansa-Stark', 0.03714483664326785)]

# %%
# Weighted Betweenness similarity 
sorted(nx.betweenness_centrality(G1,weight='weight').items(),key=lambda x:x[1],reverse = True)[0:10]
# Out:
# [('Robert-Baratheon', 0.23341885664466297),
#  ('Eddard-Stark', 0.18703429235687297),
#  ('Tyrion-Lannister', 0.15311225972516293),
#  ('Robb-Stark', 0.1024018949825402),
#  ('Catelyn-Stark', 0.10169012330302643),
#  ('Jon-Snow', 0.09027684366394043),
#  ('Jaime-Lannister', 0.07745109164464009),
#  ('Rodrik-Cassel', 0.07667992877670296),
#  ('Drogo', 0.06894355184677767),
#  ('Jorah-Mormont', 0.0627085149665795)]

# %%
# Your observations here
robert baratheon at the top of weighted betweenness 
drogo enters lists

# %% [markdown]
# ## Is there a correlation between node centrality measures?
#
# Well, lets find out.
#
#
# - __Find the correlation between following:__
#     - Weighted Degree
#     - Closeness
#     - Weighted Betweenness
#     - Weighted Eigenvector
# - __Use book 1 for the analysis (You may choose other books as well)__
# - __Calculate correlation matrix and visualize the results for all characters__
# - __Comment on the results__

# %%
df=pd.DataFrame(columns=['Weighted Degree','Closeness','Weighted Betweenness','Weighted Eigenvector'],index=list(G1.nodes))
df['Weighted Degree']=weighted_degree_centrality(G1).values()
df['Closeness']=nx.closeness_centrality(G1).values()
df['Weighted Betweenness']=nx.betweenness_centrality(G1,weight='weight').values()
df['Weighted Eigenvector']=nx.eigenvector_centrality(G1,weight='weight').values()
df
# Out:
#                                  Weighted Degree  Closeness  \
# Addam-Marbrand                          0.000611   0.323478
# Jaime-Lannister                         0.016359   0.461538
# Tywin-Lannister                         0.012286   0.449275
# Aegon-I-Targaryen                       0.000611   0.376518
# Daenerys-Targaryen                      0.030071   0.405229
# Eddard-Stark                            0.087157   0.563636
# Aemon-Targaryen-(Maester-Aemon)         0.005023   0.336957
# Alliser-Thorne                          0.005430   0.363281
# Bowen-Marsh                             0.001901   0.335740
# Chett                                   0.001290   0.333333
# Clydas                                  0.000339   0.252374
# Jeor-Mormont                            0.012286   0.416107
# Jon-Snow                                0.053217   0.493369
# Samwell-Tarly                           0.010046   0.357692
# Aerys-II-Targaryen                      0.002512   0.385892
# Brandon-Stark                           0.002783   0.380368
# Gerold-Hightower                        0.001154   0.380368
# Jon-Arryn                               0.011472   0.437647
# Robert-Baratheon                        0.063875   0.545455
# Aggo                                    0.002444   0.292913
# Drogo                                   0.017377   0.379592
# Jhogo                                   0.002919   0.292913
# Jorah-Mormont                           0.010453   0.374245
# Quaro                                   0.001425   0.292453
# Rakharo                                 0.001629   0.292453
# Albett                                  0.000747   0.332143
# Halder                                  0.003801   0.335740
# Rast                                    0.001765   0.334532
# Grenn                                   0.005770   0.336347
# Pypar                                   0.007263   0.335135
# ...                                          ...        ...
# Fogo                                    0.000272   0.217036
# Roose-Bolton                            0.001290   0.342541
# Gared                                   0.001969   0.296178
# Will-(prologue)                         0.002036   0.236341
# Oswell-Whent                            0.000204   0.275964
# Todder                                  0.002104   0.332737
# Gunthor-son-of-Gurn                     0.000475   0.338798
# Harys-Swyft                             0.000204   0.316327
# Heward                                  0.000543   0.304918
# Hobb                                    0.000339   0.330961
# Hugh                                    0.000204   0.304918
# Jafer-Flowers                           0.000204   0.251691
# Kevan-Lannister                         0.001901   0.357006
# Matthar                                 0.000204   0.330961
# Othor                                   0.000339   0.330961
# Maege-Mormont                           0.000543   0.290625
# Jonos-Bracken                           0.000204   0.254098
# Jyck                                    0.000747   0.339416
# Morrec                                  0.000679   0.339416
# Kurleket                                0.000339   0.338798
# Lancel-Lannister                        0.000204   0.353612
# Leo-Lefford                             0.000272   0.338798
# Mace-Tyrell                             0.000407   0.286154
# Lyn-Corbray                             0.000204   0.300971
# Paxter-Redwyne                          0.000204   0.222754
# Maegor-I-Targaryen                      0.000272   0.329204
# Mord                                    0.001358   0.338798
# Randyll-Tarly                           0.000339   0.263830
# Timett                                  0.000475   0.340659
# Ulf-son-of-Umar                         0.000272   0.256198
#
#                                  Weighted Betweenness  Weighted Eigenvector
# Addam-Marbrand                               0.000000              0.001551
# Jaime-Lannister                              0.077451              0.103790
# Tywin-Lannister                              0.041211              0.068416
# Aegon-I-Targaryen                            0.000000              0.005096
# Daenerys-Targaryen                           0.034182              0.025726
# Eddard-Stark                                 0.187034              0.560718
# Aemon-Targaryen-(Maester-Aemon)              0.010753              0.013992
# Alliser-Thorne                               0.026584              0.015771
# Bowen-Marsh                                  0.000814              0.004776
# Chett                                        0.002209              0.002120
# Clydas                                       0.000000              0.000150
# Jeor-Mormont                                 0.051807              0.044293
# Jon-Snow                                     0.090277              0.166858
# Samwell-Tarly                                0.040581              0.032226
# Aerys-II-Targaryen                           0.007183              0.027406
# Brandon-Stark                                0.003716              0.024805
# Gerold-Hightower                             0.039766              0.008206
# Jon-Arryn                                    0.013404              0.114162
# Robert-Baratheon                             0.233419              0.513541
# Aggo                                         0.000450              0.000852
# Drogo                                        0.068944              0.010191
# Jhogo                                        0.000291              0.001238
# Jorah-Mormont                                0.062709              0.008819
# Quaro                                        0.009188              0.000365
# Rakharo                                      0.011795              0.000332
# Albett                                       0.007169              0.001875
# Halder                                       0.007950              0.009347
# Rast                                         0.007573              0.003473
# Grenn                                        0.019104              0.013303
# Pypar                                        0.000000              0.018083
# ...                                               ...                   ...
# Fogo                                         0.000000              0.000002
# Roose-Bolton                                 0.000607              0.002458
# Gared                                        0.010123              0.000387
# Will-(prologue)                              0.000000              0.000018
# Oswell-Whent                                 0.000000              0.000053
# Todder                                       0.000000              0.005232
# Gunthor-son-of-Gurn                          0.000000              0.002283
# Harys-Swyft                                  0.000000              0.000669
# Heward                                       0.000000              0.000779
# Hobb                                         0.000000              0.001793
# Hugh                                         0.000000              0.000736
# Jafer-Flowers                                0.000000              0.000024
# Kevan-Lannister                              0.000000              0.007107
# Matthar                                      0.000000              0.001076
# Othor                                        0.000000              0.001793
# Maege-Mormont                                0.000000              0.000131
# Jonos-Bracken                                0.000000              0.000011
# Jyck                                         0.000000              0.001974
# Morrec                                       0.000000              0.001652
# Kurleket                                     0.000000              0.001631
# Lancel-Lannister                             0.000000              0.003310
# Leo-Lefford                                  0.000000              0.001304
# Mace-Tyrell                                  0.010753              0.000201
# Lyn-Corbray                                  0.000000              0.000310
# Paxter-Redwyne                               0.000000              0.000001
# Maegor-I-Targaryen                           0.000000              0.001597
# Mord                                         0.000000              0.006522
# Randyll-Tarly                                0.000000              0.000346
# Timett                                       0.009085              0.001028
# Ulf-son-of-Umar                              0.000000              0.000049
#
# [187 rows x 4 columns]

# %%
# Create a dataframe with 4 centrality measures, for all characters
# Out:
#                                    Degree  Closeness  Betweenness  Eigenvector
# Addam-Marbrand                   0.000611   0.323478     0.000000     0.001551
# Aegon-I-Targaryen                0.000611   0.376518     0.000000     0.005096
# Aemon-Targaryen-(Maester-Aemon)  0.005023   0.336957     0.010753     0.013992
# Aerys-II-Targaryen               0.002512   0.385892     0.007183     0.027406
# Aggo                             0.002444   0.292913     0.000450     0.000852
# Albett                           0.000747   0.332143     0.007169     0.001875
# Alliser-Thorne                   0.005430   0.363281     0.026584     0.015771
# Alyn                             0.002172   0.380368     0.002693     0.019102
# Arthur-Dayne                     0.000272   0.275964     0.000000     0.000071
# Arya-Stark                       0.029188   0.458128     0.028114     0.143378

# %%
# plot the measures as lines to see if they correlate
df.plot(figsize=(16,8))

# %%
# calculate Correlation matrix
df.corr()
# Out:
#                       Weighted Degree  Closeness  Weighted Betweenness  \
# Weighted Degree              1.000000   0.713617              0.857222
# Closeness                    0.713617   1.000000              0.675276
# Weighted Betweenness         0.857222   0.675276              1.000000
# Weighted Eigenvector         0.922520   0.697500              0.805318
#
#                       Weighted Eigenvector
# Weighted Degree                   0.922520
# Closeness                         0.697500
# Weighted Betweenness              0.805318
# Weighted Eigenvector              1.000000

# %%
# Your observations here 
weighted degree has highest correlation across the measures of centrality
weighted degree and weighted eigenvect correlate the best

# %% [markdown]
# ## Character Evolution : Bring the the rest of series
#
# By Studying the change in centrality throughout the series, we can create an evolution of characters as the story progresses.
#
# - __Calculate the weighted degree centrality for all five books (edge lists), and save your results in a dataframe__
#
# Hint: Fill nans with zero for values that can not be calculated  due to being extremely small

# %%
centralities=[weighted_degree_centrality(G1),weighted_degree_centrality(G2),weighted_degree_centrality(G3),weighted_degree_centrality(G4),weighted_degree_centrality(G5)]
evol_degree=pd.DataFrame(centralities)
evol_degree.fillna(0)
# Out:
#    Addam-Marbrand  Aegon-Frey-(son-of-Stevron)  Aegon-I-Targaryen  \
# 0        0.000611                     0.000000           0.000611
# 1        0.000000                     0.000000           0.001336
# 2        0.001711                     0.001062           0.000649
# 3        0.001908                     0.000000           0.000000
# 4        0.000000                     0.000000           0.000350
#
#    Aegon-Targaryen-(son-of-Rhaegar)  Aegon-V-Targaryen  \
# 0                          0.000000           0.000000
# 1                          0.000000           0.000236
# 2                          0.000177           0.000000
# 3                          0.000318           0.000318
# 4                          0.011386           0.000000
#
#    Aemon-Targaryen-(Dragonknight)  Aemon-Targaryen-(Maester-Aemon)  \
# 0                        0.000000                         0.005023
# 1                        0.000000                         0.002673
# 2                        0.000177                         0.009083
# 3                        0.000000                         0.009752
# 4                        0.000000                         0.003591
#
#    Aenys-Frey  Aeron-Greyjoy  Aerys-I-Targaryen    ...     Yellow-Dick  \
# 0    0.000000       0.000000           0.000000    ...        0.000000
# 1    0.000472       0.001730           0.000236    ...        0.000000
# 2    0.000000       0.000000           0.000000    ...        0.000000
# 3    0.000000       0.012932           0.000000    ...        0.000000
# 4    0.001139       0.000613           0.000000    ...        0.001314
#
#    Yezzan-zo-Qaggaz   Ygritte  Yohn-Royce    Yoren  Yorko-Terys    Ysilla  \
# 0          0.000000  0.000000    0.000000  0.00224     0.000000  0.000000
# 1          0.000000  0.001887    0.000000  0.00684     0.000000  0.000000
# 2          0.000000  0.007314    0.000177  0.00000     0.000000  0.000000
# 3          0.000000  0.000000    0.003922  0.00000     0.000636  0.000000
# 4          0.004204  0.001489    0.000000  0.00000     0.000000  0.004029
#
#    Yurkhaz-zo-Yunzak       Zei     Zollo
# 0            0.00000  0.000000  0.000000
# 1            0.00000  0.000000  0.000000
# 2            0.00000  0.000177  0.000472
# 3            0.00000  0.000000  0.000636
# 4            0.00035  0.000000  0.000000
#
# [5 rows x 796 columns]

# %%
# Create a character evolution dataframe based on weighted degree centrality from all books

# Fill Nans and view contents
# Out:
#    Addam-Marbrand  Aegon-Frey-(son-of-Stevron)  Aegon-I-Targaryen  \
# 0        0.000611                     0.000000           0.000611
# 1        0.000000                     0.000000           0.001336
# 2        0.001711                     0.001062           0.000649
# 3        0.001908                     0.000000           0.000000
# 4        0.000000                     0.000000           0.000350
#
#    Aegon-Targaryen-(son-of-Rhaegar)  Aegon-V-Targaryen  \
# 0                          0.000000           0.000000
# 1                          0.000000           0.000236
# 2                          0.000177           0.000000
# 3                          0.000318           0.000318
# 4                          0.011386           0.000000
#
#    Aemon-Targaryen-(Dragonknight)  Aemon-Targaryen-(Maester-Aemon)  \
# 0                        0.000000                         0.005023
# 1                        0.000000                         0.002673
# 2                        0.000177                         0.009083
# 3                        0.000000                         0.009752
# 4                        0.000000                         0.003591
#
#    Aenys-Frey  Aeron-Greyjoy  Aerys-I-Targaryen    ...     Yellow-Dick  \
# 0    0.000000       0.000000           0.000000    ...        0.000000
# 1    0.000472       0.001730           0.000236    ...        0.000000
# 2    0.000000       0.000000           0.000000    ...        0.000000
# 3    0.000000       0.012932           0.000000    ...        0.000000
# 4    0.001139       0.000613           0.000000    ...        0.001314
#
#    Yezzan-zo-Qaggaz   Ygritte  Yohn-Royce    Yoren  Yorko-Terys    Ysilla  \
# 0          0.000000  0.000000    0.000000  0.00224     0.000000  0.000000
# 1          0.000000  0.001887    0.000000  0.00684     0.000000  0.000000
# 2          0.000000  0.007314    0.000177  0.00000     0.000000  0.000000
# 3          0.000000  0.000000    0.003922  0.00000     0.000636  0.000000
# 4          0.004204  0.001489    0.000000  0.00000     0.000000  0.004029
#
#    Yurkhaz-zo-Yunzak       Zei     Zollo
# 0            0.00000  0.000000  0.000000
# 1            0.00000  0.000000  0.000000
# 2            0.00000  0.000177  0.000472
# 3            0.00000  0.000000  0.000636
# 4            0.00035  0.000000  0.000000
#
# [5 rows x 796 columns]

# %% [markdown]
# - __Identify top 10 characters i.e. having 10 highest degree centrality values, from `evol_degree_df` and create a new dataframe with their names and centrality value__

# %%
top10=evol_degree.max().sort_values(ascending=False)[0:10]
top10
# Out:
# Eddard-Stark          0.087157
# Cersei-Lannister      0.082998
# Jon-Snow              0.066649
# Tyrion-Lannister      0.065173
# Robert-Baratheon      0.063875
# Daenerys-Targaryen    0.063146
# Jaime-Lannister       0.059148
# Joffrey-Baratheon     0.049450
# Bran-Stark            0.038208
# Sansa-Stark           0.036994
# dtype: float64

# %%
# Out:
# Eddard-Stark          0.087157
# Cersei-Lannister      0.082998
# Jon-Snow              0.066649
# Tyrion-Lannister      0.065173
# Robert-Baratheon      0.063875
# Daenerys-Targaryen    0.063146
# Jaime-Lannister       0.059148
# Joffrey-Baratheon     0.049450
# Bran-Stark            0.038208
# Sansa-Stark           0.036994
# dtype: float64

# %% [markdown]
# - __Plot the evolution of weighted degree centrality of the above characters over the 5 books__
# - __Comment on your answer__

# %%
plt.figure(figsize=(16,6))
for i in top10.index:
    plt.plot(evol_degree[i])
plt.legend(top10.index)
plt.show()

# %%
# Your observations here

# %% [markdown]
# #### Repeat Above for Weighted Betweenness Centrality

# %%
betweenness=[nx.betweenness_centrality(G1),nx.betweenness_centrality(G2),nx.betweenness_centrality(G3),nx.betweenness_centrality(G4),nx.betweenness_centrality(G5)]
evol_between=pd.DataFrame(betweenness)
evol_between.fillna(0)
top10b=evol_between.max().sort_values(ascending=False)[0:10]
plt.figure(figsize=(16,6))
for i in top10b.index:
    plt.plot(evol_between[i])
plt.legend(top10b.index)
plt.show()

# %%
# Record Your observations here

# %% [markdown]
# ## Level Up: Visualize the Graphs (optional)
#
# - Use the techniques seen so far to visualize and customize the graphs
# - Study the shapes of the graphs in terms of spread , clusters etc and see if you can identify any links to the actual books (or the TV series)

# %%
plt.figure(figsize=(16,16))
nx.draw(G1,with_labels=True,pos=nx.fruchterman_reingold_layout(G1))

# %% [markdown]
# ## Summary
#
# In this lab, we looked at different centrality measures of the graph data for the ASIOF dataset. We also compared these measures to see how they correlate with each other. We also saw in practice, the difference between taking the weighted centrality measures and how it may effect the results.
